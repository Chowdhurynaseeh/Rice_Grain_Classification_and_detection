# %%
import os
from glob import glob # extract path of each file
import pandas as pd # data preprocessing
from xml.etree import ElementTree as et # parse information from XML
from functools import reduce

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# step-1: get path of each xml file
xmlfiles = glob('./data_images/*.xml')
# replace \\ with /
replace_text = lambda x: x.replace('\\','/')
xmlfiles = list(map(replace_text,xmlfiles))

# %%
xmlfiles
# Out:
# ['./data_images/basmati (1).xml',
#  './data_images/basmati (10).xml',
#  './data_images/basmati (100).xml',
#  './data_images/basmati (101).xml',
#  './data_images/basmati (102).xml',
#  './data_images/basmati (103).xml',
#  './data_images/basmati (104).xml',
#  './data_images/basmati (105).xml',
#  './data_images/basmati (106).xml',
#  './data_images/basmati (107).xml',
#  './data_images/basmati (108).xml',
#  './data_images/basmati (109).xml',
#  './data_images/basmati (11).xml',
#  './data_images/basmati (110).xml',
#  './data_images/basmati (111).xml',
#  './data_images/basmati (112).xml',
#  './data_images/basmati (113).xml',
#  './data_images/basmati (114).xml',
#  './data_images/basmati (115).xml',
#  './data_images/basmati (116).xml',
#  './data_images/basmati (117).xml',
#  './data_images/basmati (118).xml',
#  './data_images/basmati (119).xml',
#  './data_images/basmati (12).xml',
#  './data_images/basmati (120).xml',
#  './data_images/basmati (121).xml',
#  './data_images/basmati (122).xml',
#  './data_images/basmati (123).xml',
#  './data_images/basmati (124).xml',
#  './data_images/basmati (125).xml',
#  './data_images/basmati (126).xml',
#  './data_images/basmati (127).xml',
#  './data_images/basmati (128).xml',
#  './data_images/basmati (129).xml',
#  './data_images/basmati (13).xml',
#  './data_images/basmati (130).xml',
#  './data_images/basmati (131).xml',
#  './data_images/basmati (132).xml',
#  './data_images/basmati (133).xml',
#  './data_images/basmati (134).xml',
#  './data_images/basmati (135).xml',
#  './data_images/basmati (136).xml',
#  './data_images/basmati (137).xml',
#  './data_images/basmati (138).xml',
#  './data_images/basmati (139).xml',
#  './data_images/basmati (14).xml',
#  './data_images/basmati (140).xml',
#  './data_images/basmati (141).xml',
#  './data_images/basmati (142).xml',
#  './data_images/basmati (143).xml',
#  './data_images/basmati (144).xml',
#  './data_images/basmati (145).xml',
#  './data_images/basmati (146).xml',
#  './data_images/basmati (147).xml',
#  './data_images/basmati (148).xml',
#  './data_images/basmati (149).xml',
#  './data_images/basmati (15).xml',
#  './data_images/basmati (150).xml',
#  './data_images/basmati (151).xml',
#  './data_images/basmati (152).xml',
#  './data_images/basmati (153).xml',
#  './data_images/basmati (154).xml',
#  './data_images/basmati (155).xml',
#  './data_images/basmati (156).xml',
#  './data_images/basmati (157).xml',
#  './data_images/basmati (158).xml',
#  './data_images/basmati (159).xml',
#  './data_images/basmati (16).xml',
#  './data_images/basmati (160).xml',
#  './data_images/basmati (161).xml',
#  './data_images/basmati (162).xml',
#  './data_images/basmati (163).xml',
#  './data_images/basmati (164).xml',
#  './data_images/basmati (165).xml',
#  './data_images/basmati (166).xml',
#  './data_images/basmati (167).xml',
#  './data_images/basmati (168).xml',
#  './data_images/basmati (169).xml',
#  './data_images/basmati (17).xml',
#  './data_images/basmati (170).xml',
#  './data_images/basmati (171).xml',
#  './data_images/basmati (172).xml',
#  './data_images/basmati (173).xml',
#  './data_images/basmati (174).xml',
#  './data_images/basmati (175).xml',
#  './data_images/basmati (176).xml',
#  './data_images/basmati (177).xml',
#  './data_images/basmati (178).xml',
#  './data_images/basmati (179).xml',
#  './data_images/basmati (18).xml',
#  './data_images/basmati (180).xml',
#  './data_images/basmati (181).xml',
#  './data_images/basmati (182).xml',
#  './data_images/basmati (183).xml',
#  './data_images/basmati (184).xml',
#  './data_images/basmati (185).xml',
#  './data_images/basmati (186).xml',
#  './data_images/basmati (187).xml',
#  './data_images/basmati (188).xml',
#  './data_images/basmati (189).xml',
#  './data_images/basmati (19).xml',
#  './data_images/basmati (190).xml',
#  './data_images/basmati (191).xml',
#  './data_images/basmati (192).xml',
#  './data_images/basmati (193).xml',
#  './data_images/basmati (194).xml',
#  './data_images/basmati (195).xml',
#  './data_images/basmati (196).xml',
#  './data_images/basmati (197).xml',
#  './data_images/basmati (198).xml',
#  './data_images/basmati (199).xml',
#  './data_images/basmati (2).xml',
#  './data_images/basmati (20).xml',
#  './data_images/basmati (200).xml',
#  './data_images/basmati (201).xml',
#  './data_images/basmati (202).xml',
#  './data_images/basmati (203).xml',
#  './data_images/basmati (204).xml',
#  './data_images/basmati (205).xml',
#  './data_images/basmati (206).xml',
#  './data_images/basmati (207).xml',
#  './data_images/basmati (208).xml',
#  './data_images/basmati (209).xml',
#  './data_images/basmati (21).xml',
#  './data_images/basmati (210).xml',
#  './data_images/basmati (211).xml',
#  './data_images/basmati (212).xml',
#  './data_images/basmati (213).xml',
#  './data_images/basmati (214).xml',
#  './data_images/basmati (215).xml',
#  './data_images/basmati (216).xml',
#  './data_images/basmati (217).xml',
#  './data_images/basmati (218).xml',
#  './data_images/basmati (219).xml',
#  './data_images/basmati (22).xml',
#  './data_images/basmati (220).xml',
#  './data_images/basmati (221).xml',
#  './data_images/basmati (222).xml',
#  './data_images/basmati (223).xml',
#  './data_images/basmati (224).xml',
#  './data_images/basmati (225).xml',
#  './data_images/basmati (226).xml',
#  './data_images/basmati (227).xml',
#  './data_images/basmati (228).xml',
#  './data_images/basmati (229).xml',
#  './data_images/basmati (23).xml',
#  './data_images/basmati (230).xml',
#  './data_images/basmati (231).xml',
#  './data_images/basmati (232).xml',
#  './data_images/basmati (233).xml',
#  './data_images/basmati (234).xml',
#  './data_images/basmati (235).xml',
#  './data_images/basmati (236).xml',
#  './data_images/basmati (237).xml',
#  './data_images/basmati (238).xml',
#  './data_images/basmati (239).xml',
#  './data_images/basmati (24).xml',
#  './data_images/basmati (240).xml',
#  './data_images/basmati (241).xml',
#  './data_images/basmati (242).xml',
#  './data_images/basmati (243).xml',
#  './data_images/basmati (244).xml',
#  './data_images/basmati (245).xml',
#  './data_images/basmati (246).xml',
#  './data_images/basmati (247).xml',
#  './data_images/basmati (248).xml',
#  './data_images/basmati (249).xml',
#  './data_images/basmati (25).xml',
#  './data_images/basmati (250).xml',
#  './data_images/basmati (251).xml',
#  './data_images/basmati (252).xml',
#  './data_images/basmati (253).xml',
#  './data_images/basmati (254).xml',
#  './data_images/basmati (255).xml',
#  './data_images/basmati (256).xml',
#  './data_images/basmati (257).xml',
#  './data_images/basmati (258).xml',
#  './data_images/basmati (259).xml',
#  './data_images/basmati (26).xml',
#  './data_images/basmati (260).xml',
#  './data_images/basmati (261).xml',
#  './data_images/basmati (262).xml',
#  './data_images/basmati (263).xml',
#  './data_images/basmati (264).xml',
#  './data_images/basmati (265).xml',
#  './data_images/basmati (266).xml',
#  './data_images/basmati (267).xml',
#  './data_images/basmati (268).xml',
#  './data_images/basmati (269).xml',
#  './data_images/basmati (27).xml',
#  './data_images/basmati (270).xml',
#  './data_images/basmati (271).xml',
#  './data_images/basmati (272).xml',
#  './data_images/basmati (273).xml',
#  './data_images/basmati (274).xml',
#  './data_images/basmati (275).xml',
#  './data_images/basmati (276).xml',
#  './data_images/basmati (277).xml',
#  './data_images/basmati (278).xml',
#  './data_images/basmati (279).xml',
#  './data_images/basmati (28).xml',
#  './data_images/basmati (280).xml',
#  './data_images/basmati (281).xml',
#  './data_images/basmati (282).xml',
#  './data_images/basmati (283).xml',
#  './data_images/basmati (284).xml',
#  './data_images/basmati (285).xml',
#  './data_images/basmati (286).xml',
#  './data_images/basmati (287).xml',
#  './data_images/basmati (288).xml',
#  './data_images/basmati (289).xml',
#  './data_images/basmati (29).xml',
#  './data_images/basmati (290).xml',
#  './data_images/basmati (291).xml',
#  './data_images/basmati (292).xml',
#  './data_images/basmati (293).xml',
#  './data_images/basmati (294).xml',
#  './data_images/basmati (295).xml',
#  './data_images/basmati (296).xml',
#  './data_images/basmati (297).xml',
#  './data_images/basmati (298).xml',
#  './data_images/basmati (299).xml',
#  './data_images/basmati (3).xml',
#  './data_images/basmati (30).xml',
#  './data_images/basmati (300).xml',
#  './data_images/basmati (301).xml',
#  './data_images/basmati (302).xml',
#  './data_images/basmati (303).xml',
#  './data_images/basmati (304).xml',
#  './data_images/basmati (305).xml',
#  './data_images/basmati (306).xml',
#  './data_images/basmati (307).xml',
#  './data_images/basmati (308).xml',
#  './data_images/basmati (309).xml',
#  './data_images/basmati (31).xml',
#  './data_images/basmati (310).xml',
#  './data_images/basmati (311).xml',
#  './data_images/basmati (312).xml',
#  './data_images/basmati (313).xml',
#  './data_images/basmati (314).xml',
#  './data_images/basmati (315).xml',
#  './data_images/basmati (316).xml',
#  './data_images/basmati (317).xml',
#  './data_images/basmati (318).xml',
#  './data_images/basmati (319).xml',
#  './data_images/basmati (32).xml',
#  './data_images/basmati (320).xml',
#  './data_images/basmati (321).xml',
#  './data_images/basmati (322).xml',
#  './data_images/basmati (323).xml',
#  './data_images/basmati (324).xml',
#  './data_images/basmati (325).xml',
#  './data_images/basmati (326).xml',
#  './data_images/basmati (327).xml',
#  './data_images/basmati (328).xml',
#  './data_images/basmati (329).xml',
#  './data_images/basmati (33).xml',
#  './data_images/basmati (330).xml',
#  './data_images/basmati (331).xml',
#  './data_images/basmati (332).xml',
#  './data_images/basmati (333).xml',
#  './data_images/basmati (334).xml',
#  './data_images/basmati (335).xml',
#  './data_images/basmati (336).xml',
#  './data_images/basmati (337).xml',
#  './data_images/basmati (338).xml',
#  './data_images/basmati (339).xml',
#  './data_images/basmati (34).xml',
#  './data_images/basmati (340).xml',
#  './data_images/basmati (341).xml',
#  './data_images/basmati (342).xml',
#  './data_images/basmati (343).xml',
#  './data_images/basmati (344).xml',
#  './data_images/basmati (345).xml',
#  './data_images/basmati (346).xml',
#  './data_images/basmati (347).xml',
#  './data_images/basmati (348).xml',
#  './data_images/basmati (349).xml',
#  './data_images/basmati (35).xml',
#  './data_images/basmati (350).xml',
#  './data_images/basmati (351).xml',
#  './data_images/basmati (352).xml',
#  './data_images/basmati (353).xml',
#  './data_images/basmati (354).xml',
#  './data_images/basmati (355).xml',
#  './data_images/basmati (356).xml',
#  './data_images/basmati (357).xml',
#  './data_images/basmati (358).xml',
#  './data_images/basmati (359).xml',
#  './data_images/basmati (36).xml',
#  './data_images/basmati (360).xml',
#  './data_images/basmati (361).xml',
#  './data_images/basmati (362).xml',
#  './data_images/basmati (363).xml',
#  './data_images/basmati (364).xml',
#  './data_images/basmati (365).xml',
#  './data_images/basmati (366).xml',
#  './data_images/basmati (367).xml',
#  './data_images/basmati (368).xml',
#  './data_images/basmati (369).xml',
#  './data_images/basmati (37).xml',
#  './data_images/basmati (370).xml',
#  './data_images/basmati (371).xml',
#  './data_images/basmati (372).xml',
#  './data_images/basmati (373).xml',
#  './data_images/basmati (374).xml',
#  './data_images/basmati (375).xml',
#  './data_images/basmati (376).xml',
#  './data_images/basmati (377).xml',
#  './data_images/basmati (378).xml',
#  './data_images/basmati (379).xml',
#  './data_images/basmati (38).xml',
#  './data_images/basmati (380).xml',
#  './data_images/basmati (381).xml',
#  './data_images/basmati (382).xml',
#  './data_images/basmati (383).xml',
#  './data_images/basmati (384).xml',
#  './data_images/basmati (385).xml',
#  './data_images/basmati (386).xml',
#  './data_images/basmati (387).xml',
#  './data_images/basmati (388).xml',
#  './data_images/basmati (389).xml',
#  './data_images/basmati (39).xml',
#  './data_images/basmati (390).xml',
#  './data_images/basmati (391).xml',
#  './data_images/basmati (392).xml',
#  './data_images/basmati (393).xml',
#  './data_images/basmati (394).xml',
#  './data_images/basmati (395).xml',
#  './data_images/basmati (396).xml',
#  './data_images/basmati (397).xml',
#  './data_images/basmati (398).xml',
#  './data_images/basmati (399).xml',
#  './data_images/basmati (4).xml',
#  './data_images/basmati (40).xml',
#  './data_images/basmati (400).xml',
#  './data_images/basmati (401).xml',
#  './data_images/basmati (402).xml',
#  './data_images/basmati (403).xml',
#  './data_images/basmati (404).xml',
#  './data_images/basmati (405).xml',
#  './data_images/basmati (406).xml',
#  './data_images/basmati (407).xml',
#  './data_images/basmati (408).xml',
#  './data_images/basmati (409).xml',
#  './data_images/basmati (41).xml',
#  './data_images/basmati (410).xml',
#  './data_images/basmati (411).xml',
#  './data_images/basmati (412).xml',
#  './data_images/basmati (413).xml',
#  './data_images/basmati (414).xml',
#  './data_images/basmati (415).xml',
#  './data_images/basmati (416).xml',
#  './data_images/basmati (417).xml',
#  './data_images/basmati (418).xml',
#  './data_images/basmati (419).xml',
#  './data_images/basmati (42).xml',
#  './data_images/basmati (420).xml',
#  './data_images/basmati (421).xml',
#  './data_images/basmati (422).xml',
#  './data_images/basmati (423).xml',
#  './data_images/basmati (424).xml',
#  './data_images/basmati (425).xml',
#  './data_images/basmati (426).xml',
#  './data_images/basmati (427).xml',
#  './data_images/basmati (428).xml',
#  './data_images/basmati (429).xml',
#  './data_images/basmati (43).xml',
#  './data_images/basmati (430).xml',
#  './data_images/basmati (431).xml',
#  './data_images/basmati (432).xml',
#  './data_images/basmati (433).xml',
#  './data_images/basmati (434).xml',
#  './data_images/basmati (435).xml',
#  './data_images/basmati (436).xml',
#  './data_images/basmati (437).xml',
#  './data_images/basmati (438).xml',
#  './data_images/basmati (439).xml',
#  './data_images/basmati (44).xml',
#  './data_images/basmati (440).xml',
#  './data_images/basmati (441).xml',
#  './data_images/basmati (442).xml',
#  './data_images/basmati (443).xml',
#  './data_images/basmati (444).xml',
#  './data_images/basmati (445).xml',
#  './data_images/basmati (446).xml',
#  './data_images/basmati (447).xml',
#  './data_images/basmati (448).xml',
#  './data_images/basmati (449).xml',
#  './data_images/basmati (45).xml',
#  './data_images/basmati (450).xml',
#  './data_images/basmati (451).xml',
#  './data_images/basmati (452).xml',
#  './data_images/basmati (453).xml',
#  './data_images/basmati (454).xml',
#  './data_images/basmati (455).xml',
#  './data_images/basmati (456).xml',
#  './data_images/basmati (457).xml',
#  './data_images/basmati (458).xml',
#  './data_images/basmati (459).xml',
#  './data_images/basmati (46).xml',
#  './data_images/basmati (460).xml',
#  './data_images/basmati (461).xml',
#  './data_images/basmati (462).xml',
#  './data_images/basmati (463).xml',
#  './data_images/basmati (464).xml',
#  './data_images/basmati (465).xml',
#  './data_images/basmati (466).xml',
#  './data_images/basmati (467).xml',
#  './data_images/basmati (468).xml',
#  './data_images/basmati (469).xml',
#  './data_images/basmati (47).xml',
#  './data_images/basmati (470).xml',
#  './data_images/basmati (471).xml',
#  './data_images/basmati (472).xml',
#  './data_images/basmati (473).xml',
#  './data_images/basmati (474).xml',
#  './data_images/basmati (475).xml',
#  './data_images/basmati (476).xml',
#  './data_images/basmati (477).xml',
#  './data_images/basmati (478).xml',
#  './data_images/basmati (479).xml',
#  './data_images/basmati (48).xml',
#  './data_images/basmati (480).xml',
#  './data_images/basmati (481).xml',
#  './data_images/basmati (482).xml',
#  './data_images/basmati (483).xml',
#  './data_images/basmati (484).xml',
#  './data_images/basmati (485).xml',
#  './data_images/basmati (486).xml',
#  './data_images/basmati (487).xml',
#  './data_images/basmati (488).xml',
#  './data_images/basmati (489).xml',
#  './data_images/basmati (49).xml',
#  './data_images/basmati (490).xml',
#  './data_images/basmati (491).xml',
#  './data_images/basmati (492).xml',
#  './data_images/basmati (493).xml',
#  './data_images/basmati (494).xml',
#  './data_images/basmati (495).xml',
#  './data_images/basmati (496).xml',
#  './data_images/basmati (497).xml',
#  './data_images/basmati (498).xml',
#  './data_images/basmati (499).xml',
#  './data_images/basmati (5).xml',
#  './data_images/basmati (50).xml',
#  './data_images/basmati (500).xml',
#  './data_images/basmati (501).xml',
#  './data_images/basmati (502).xml',
#  './data_images/basmati (503).xml',
#  './data_images/basmati (504).xml',
#  './data_images/basmati (505).xml',
#  './data_images/basmati (506).xml',
#  './data_images/basmati (507).xml',
#  './data_images/basmati (508).xml',
#  './data_images/basmati (509).xml',
#  './data_images/basmati (51).xml',
#  './data_images/basmati (510).xml',
#  './data_images/basmati (511).xml',
#  './data_images/basmati (512).xml',
#  './data_images/basmati (513).xml',
#  './data_images/basmati (514).xml',
#  './data_images/basmati (515).xml',
#  './data_images/basmati (516).xml',
#  './data_images/basmati (517).xml',
#  './data_images/basmati (518).xml',
#  './data_images/basmati (519).xml',
#  './data_images/basmati (52).xml',
#  './data_images/basmati (520).xml',
#  './data_images/basmati (521).xml',
#  './data_images/basmati (522).xml',
#  './data_images/basmati (523).xml',
#  './data_images/basmati (524).xml',
#  './data_images/basmati (525).xml',
#  './data_images/basmati (526).xml',
#  './data_images/basmati (527).xml',
#  './data_images/basmati (528).xml',
#  './data_images/basmati (529).xml',
#  './data_images/basmati (53).xml',
#  './data_images/basmati (530).xml',
#  './data_images/basmati (531).xml',
#  './data_images/basmati (532).xml',
#  './data_images/basmati (533).xml',
#  './data_images/basmati (534).xml',
#  './data_images/basmati (535).xml',
#  './data_images/basmati (536).xml',
#  './data_images/basmati (537).xml',
#  './data_images/basmati (538).xml',
#  './data_images/basmati (539).xml',
#  './data_images/basmati (54).xml',
#  './data_images/basmati (540).xml',
#  './data_images/basmati (541).xml',
#  './data_images/basmati (542).xml',
#  './data_images/basmati (543).xml',
#  './data_images/basmati (544).xml',
#  './data_images/basmati (545).xml',
#  './data_images/basmati (546).xml',
#  './data_images/basmati (547).xml',
#  './data_images/basmati (548).xml',
#  './data_images/basmati (549).xml',
#  './data_images/basmati (55).xml',
#  './data_images/basmati (550).xml',
#  './data_images/basmati (551).xml',
#  './data_images/basmati (552).xml',
#  './data_images/basmati (553).xml',
#  './data_images/basmati (554).xml',
#  './data_images/basmati (555).xml',
#  './data_images/basmati (556).xml',
#  './data_images/basmati (557).xml',
#  './data_images/basmati (558).xml',
#  './data_images/basmati (559).xml',
#  './data_images/basmati (560).xml',
#  './data_images/basmati (561).xml',
#  './data_images/basmati (562).xml',
#  './data_images/basmati (563).xml',
#  './data_images/basmati (564).xml',
#  './data_images/basmati (565).xml',
#  './data_images/basmati (566).xml',
#  './data_images/basmati (567).xml',
#  './data_images/basmati (568).xml',
#  './data_images/basmati (569).xml',
#  './data_images/basmati (570).xml',
#  './data_images/basmati (571).xml',
#  './data_images/basmati (572).xml',
#  './data_images/basmati (573).xml',
#  './data_images/basmati (574).xml',
#  './data_images/basmati (575).xml',
#  './data_images/basmati (576).xml',
#  './data_images/basmati (577).xml',
#  './data_images/basmati (578).xml',
#  './data_images/basmati (579).xml',
#  './data_images/basmati (58).xml',
#  './data_images/basmati (580).xml',
#  './data_images/basmati (581).xml',
#  './data_images/basmati (582).xml',
#  './data_images/basmati (583).xml',
#  './data_images/basmati (584).xml',
#  './data_images/basmati (585).xml',
#  './data_images/basmati (586).xml',
#  './data_images/basmati (587).xml',
#  './data_images/basmati (588).xml',
#  './data_images/basmati (589).xml',
#  './data_images/basmati (59).xml',
#  './data_images/basmati (590).xml',
#  './data_images/basmati (591).xml',
#  './data_images/basmati (592).xml',
#  './data_images/basmati (593).xml',
#  './data_images/basmati (594).xml',
#  './data_images/basmati (595).xml',
#  './data_images/basmati (596).xml',
#  './data_images/basmati (597).xml',
#  './data_images/basmati (598).xml',
#  './data_images/basmati (599).xml',
#  './data_images/basmati (6).xml',
#  './data_images/basmati (60).xml',
#  './data_images/basmati (600).xml',
#  './data_images/basmati (601).xml',
#  './data_images/basmati (602).xml',
#  './data_images/basmati (603).xml',
#  './data_images/basmati (604).xml',
#  './data_images/basmati (605).xml',
#  './data_images/basmati (61).xml',
#  './data_images/basmati (62).xml',
#  './data_images/basmati (63).xml',
#  './data_images/basmati (64).xml',
#  './data_images/basmati (65).xml',
#  './data_images/basmati (66).xml',
#  './data_images/basmati (67).xml',
#  './data_images/basmati (68).xml',
#  './data_images/basmati (69).xml',
#  './data_images/basmati (7).xml',
#  './data_images/basmati (70).xml',
#  './data_images/basmati (71).xml',
#  './data_images/basmati (72).xml',
#  './data_images/basmati (73).xml',
#  './data_images/basmati (74).xml',
#  './data_images/basmati (75).xml',
#  './data_images/basmati (76).xml',
#  './data_images/basmati (77).xml',
#  './data_images/basmati (78).xml',
#  './data_images/basmati (79).xml',
#  './data_images/basmati (8).xml',
#  './data_images/basmati (80).xml',
#  './data_images/basmati (81).xml',
#  './data_images/basmati (82).xml',
#  './data_images/basmati (83).xml',
#  './data_images/basmati (84).xml',
#  './data_images/basmati (85).xml',
#  './data_images/basmati (86).xml',
#  './data_images/basmati (87).xml',
#  './data_images/basmati (88).xml',
#  './data_images/basmati (89).xml',
#  './data_images/basmati (9).xml',
#  './data_images/basmati (90).xml',
#  './data_images/basmati (91).xml',
#  './data_images/basmati (92).xml',
#  './data_images/basmati (93).xml',
#  './data_images/basmati (94).xml',
#  './data_images/basmati (95).xml',
#  './data_images/basmati (96).xml',
#  './data_images/basmati (97).xml',
#  './data_images/basmati (98).xml',
#  './data_images/basmati (99).xml',
#  './data_images/chinigura (1).xml',
#  './data_images/chinigura (10).xml',
#  './data_images/chinigura (100).xml',
#  './data_images/chinigura (101).xml',
#  './data_images/chinigura (102).xml',
#  './data_images/chinigura (103).xml',
#  './data_images/chinigura (104).xml',
#  './data_images/chinigura (105).xml',
#  './data_images/chinigura (106).xml',
#  './data_images/chinigura (107).xml',
#  './data_images/chinigura (108).xml',
#  './data_images/chinigura (109).xml',
#  './data_images/chinigura (11).xml',
#  './data_images/chinigura (110).xml',
#  './data_images/chinigura (111).xml',
#  './data_images/chinigura (112).xml',
#  './data_images/chinigura (113).xml',
#  './data_images/chinigura (114).xml',
#  './data_images/chinigura (115).xml',
#  './data_images/chinigura (116).xml',
#  './data_images/chinigura (117).xml',
#  './data_images/chinigura (118).xml',
#  './data_images/chinigura (119).xml',
#  './data_images/chinigura (12).xml',
#  './data_images/chinigura (120).xml',
#  './data_images/chinigura (121).xml',
#  './data_images/chinigura (122).xml',
#  './data_images/chinigura (123).xml',
#  './data_images/chinigura (124).xml',
#  './data_images/chinigura (125).xml',
#  './data_images/chinigura (126).xml',
#  './data_images/chinigura (127).xml',
#  './data_images/chinigura (128).xml',
#  './data_images/chinigura (129).xml',
#  './data_images/chinigura (13).xml',
#  './data_images/chinigura (130).xml',
#  './data_images/chinigura (131).xml',
#  './data_images/chinigura (132).xml',
#  './data_images/chinigura (133).xml',
#  './data_images/chinigura (134).xml',
#  './data_images/chinigura (135).xml',
#  './data_images/chinigura (136).xml',
#  './data_images/chinigura (137).xml',
#  './data_images/chinigura (138).xml',
#  './data_images/chinigura (139).xml',
#  './data_images/chinigura (14).xml',
#  './data_images/chinigura (140).xml',
#  './data_images/chinigura (141).xml',
#  './data_images/chinigura (142).xml',
#  './data_images/chinigura (143).xml',
#  './data_images/chinigura (144).xml',
#  './data_images/chinigura (145).xml',
#  './data_images/chinigura (146).xml',
#  './data_images/chinigura (147).xml',
#  './data_images/chinigura (148).xml',
#  './data_images/chinigura (149).xml',
#  './data_images/chinigura (15).xml',
#  './data_images/chinigura (150).xml',
#  './data_images/chinigura (151).xml',
#  './data_images/chinigura (152).xml',
#  './data_images/chinigura (153).xml',
#  './data_images/chinigura (154).xml',
#  './data_images/chinigura (155).xml',
#  './data_images/chinigura (156).xml',
#  './data_images/chinigura (157).xml',
#  './data_images/chinigura (158).xml',
#  './data_images/chinigura (159).xml',
#  './data_images/chinigura (16).xml',
#  './data_images/chinigura (160).xml',
#  './data_images/chinigura (161).xml',
#  './data_images/chinigura (162).xml',
#  './data_images/chinigura (163).xml',
#  './data_images/chinigura (164).xml',
#  './data_images/chinigura (165).xml',
#  './data_images/chinigura (166).xml',
#  './data_images/chinigura (167).xml',
#  './data_images/chinigura (168).xml',
#  './data_images/chinigura (169).xml',
#  './data_images/chinigura (17).xml',
#  './data_images/chinigura (170).xml',
#  './data_images/chinigura (171).xml',
#  './data_images/chinigura (172).xml',
#  './data_images/chinigura (173).xml',
#  './data_images/chinigura (174).xml',
#  './data_images/chinigura (175).xml',
#  './data_images/chinigura (176).xml',
#  './data_images/chinigura (177).xml',
#  './data_images/chinigura (178).xml',
#  './data_images/chinigura (179).xml',
#  './data_images/chinigura (18).xml',
#  './data_images/chinigura (180).xml',
#  './data_images/chinigura (181).xml',
#  './data_images/chinigura (182).xml',
#  './data_images/chinigura (183).xml',
#  './data_images/chinigura (184).xml',
#  './data_images/chinigura (185).xml',
#  './data_images/chinigura (186).xml',
#  './data_images/chinigura (187).xml',
#  './data_images/chinigura (188).xml',
#  './data_images/chinigura (189).xml',
#  './data_images/chinigura (19).xml',
#  './data_images/chinigura (190).xml',
#  './data_images/chinigura (191).xml',
#  './data_images/chinigura (192).xml',
#  './data_images/chinigura (193).xml',
#  './data_images/chinigura (194).xml',
#  './data_images/chinigura (195).xml',
#  './data_images/chinigura (196).xml',
#  './data_images/chinigura (197).xml',
#  './data_images/chinigura (198).xml',
#  './data_images/chinigura (199).xml',
#  './data_images/chinigura (2).xml',
#  './data_images/chinigura (20).xml',
#  './data_images/chinigura (200).xml',
#  './data_images/chinigura (201).xml',
#  './data_images/chinigura (202).xml',
#  './data_images/chinigura (203).xml',
#  './data_images/chinigura (204).xml',
#  './data_images/chinigura (205).xml',
#  './data_images/chinigura (206).xml',
#  './data_images/chinigura (207).xml',
#  './data_images/chinigura (208).xml',
#  './data_images/chinigura (209).xml',
#  './data_images/chinigura (21).xml',
#  './data_images/chinigura (210).xml',
#  './data_images/chinigura (211).xml',
#  './data_images/chinigura (212).xml',
#  './data_images/chinigura (213).xml',
#  './data_images/chinigura (214).xml',
#  './data_images/chinigura (215).xml',
#  './data_images/chinigura (216).xml',
#  './data_images/chinigura (217).xml',
#  './data_images/chinigura (218).xml',
#  './data_images/chinigura (219).xml',
#  './data_images/chinigura (22).xml',
#  './data_images/chinigura (220).xml',
#  './data_images/chinigura (221).xml',
#  './data_images/chinigura (222).xml',
#  './data_images/chinigura (223).xml',
#  './data_images/chinigura (224).xml',
#  './data_images/chinigura (225).xml',
#  './data_images/chinigura (226).xml',
#  './data_images/chinigura (227).xml',
#  './data_images/chinigura (228).xml',
#  './data_images/chinigura (229).xml',
#  './data_images/chinigura (23).xml',
#  './data_images/chinigura (230).xml',
#  './data_images/chinigura (231).xml',
#  './data_images/chinigura (232).xml',
#  './data_images/chinigura (233).xml',
#  './data_images/chinigura (234).xml',
#  './data_images/chinigura (235).xml',
#  './data_images/chinigura (236).xml',
#  './data_images/chinigura (237).xml',
#  './data_images/chinigura (238).xml',
#  './data_images/chinigura (239).xml',
#  './data_images/chinigura (24).xml',
#  './data_images/chinigura (240).xml',
#  './data_images/chinigura (241).xml',
#  './data_images/chinigura (242).xml',
#  './data_images/chinigura (243).xml',
#  './data_images/chinigura (244).xml',
#  './data_images/chinigura (245).xml',
#  './data_images/chinigura (246).xml',
#  './data_images/chinigura (247).xml',
#  './data_images/chinigura (248).xml',
#  './data_images/chinigura (249).xml',
#  './data_images/chinigura (25).xml',
#  './data_images/chinigura (250).xml',
#  './data_images/chinigura (251).xml',
#  './data_images/chinigura (252).xml',
#  './data_images/chinigura (253).xml',
#  './data_images/chinigura (254).xml',
#  './data_images/chinigura (255).xml',
#  './data_images/chinigura (256).xml',
#  './data_images/chinigura (257).xml',
#  './data_images/chinigura (258).xml',
#  './data_images/chinigura (259).xml',
#  './data_images/chinigura (26).xml',
#  './data_images/chinigura (260).xml',
#  './data_images/chinigura (261).xml',
#  './data_images/chinigura (262).xml',
#  './data_images/chinigura (263).xml',
#  './data_images/chinigura (264).xml',
#  './data_images/chinigura (265).xml',
#  './data_images/chinigura (266).xml',
#  './data_images/chinigura (267).xml',
#  './data_images/chinigura (268).xml',
#  './data_images/chinigura (269).xml',
#  './data_images/chinigura (27).xml',
#  './data_images/chinigura (270).xml',
#  './data_images/chinigura (271).xml',
#  './data_images/chinigura (272).xml',
#  './data_images/chinigura (273).xml',
#  './data_images/chinigura (274).xml',
#  './data_images/chinigura (275).xml',
#  './data_images/chinigura (276).xml',
#  './data_images/chinigura (277).xml',
#  './data_images/chinigura (278).xml',
#  './data_images/chinigura (279).xml',
#  './data_images/chinigura (28).xml',
#  './data_images/chinigura (280).xml',
#  './data_images/chinigura (281).xml',
#  './data_images/chinigura (282).xml',
#  './data_images/chinigura (283).xml',
#  './data_images/chinigura (284).xml',
#  './data_images/chinigura (285).xml',
#  './data_images/chinigura (286).xml',
#  './data_images/chinigura (287).xml',
#  './data_images/chinigura (288).xml',
#  './data_images/chinigura (289).xml',
#  './data_images/chinigura (29).xml',
#  './data_images/chinigura (290).xml',
#  './data_images/chinigura (291).xml',
#  './data_images/chinigura (292).xml',
#  './data_images/chinigura (293).xml',
#  './data_images/chinigura (294).xml',
#  './data_images/chinigura (295).xml',
#  './data_images/chinigura (296).xml',
#  './data_images/chinigura (297).xml',
#  './data_images/chinigura (298).xml',
#  './data_images/chinigura (299).xml',
#  './data_images/chinigura (3).xml',
#  './data_images/chinigura (30).xml',
#  './data_images/chinigura (300).xml',
#  './data_images/chinigura (301).xml',
#  './data_images/chinigura (302).xml',
#  './data_images/chinigura (303).xml',
#  './data_images/chinigura (304).xml',
#  './data_images/chinigura (305).xml',
#  './data_images/chinigura (306).xml',
#  './data_images/chinigura (307).xml',
#  './data_images/chinigura (308).xml',
#  './data_images/chinigura (309).xml',
#  './data_images/chinigura (31).xml',
#  './data_images/chinigura (310).xml',
#  './data_images/chinigura (311).xml',
#  './data_images/chinigura (312).xml',
#  './data_images/chinigura (313).xml',
#  './data_images/chinigura (314).xml',
#  './data_images/chinigura (315).xml',
#  './data_images/chinigura (316).xml',
#  './data_images/chinigura (317).xml',
#  './data_images/chinigura (318).xml',
#  './data_images/chinigura (319).xml',
#  './data_images/chinigura (32).xml',
#  './data_images/chinigura (320).xml',
#  './data_images/chinigura (321).xml',
#  './data_images/chinigura (322).xml',
#  './data_images/chinigura (323).xml',
#  './data_images/chinigura (324).xml',
#  './data_images/chinigura (325).xml',
#  './data_images/chinigura (326).xml',
#  './data_images/chinigura (327).xml',
#  './data_images/chinigura (328).xml',
#  './data_images/chinigura (329).xml',
#  './data_images/chinigura (33).xml',
#  './data_images/chinigura (330).xml',
#  './data_images/chinigura (331).xml',
#  './data_images/chinigura (332).xml',
#  './data_images/chinigura (333).xml',
#  './data_images/chinigura (334).xml',
#  './data_images/chinigura (335).xml',
#  './data_images/chinigura (336).xml',
#  './data_images/chinigura (337).xml',
#  './data_images/chinigura (338).xml',
#  './data_images/chinigura (339).xml',
#  './data_images/chinigura (34).xml',
#  './data_images/chinigura (340).xml',
#  './data_images/chinigura (341).xml',
#  './data_images/chinigura (342).xml',
#  './data_images/chinigura (343).xml',
#  './data_images/chinigura (344).xml',
#  './data_images/chinigura (345).xml',
#  './data_images/chinigura (346).xml',
#  './data_images/chinigura (347).xml',
#  './data_images/chinigura (348).xml',
#  './data_images/chinigura (349).xml',
#  './data_images/chinigura (35).xml',
#  './data_images/chinigura (350).xml',
#  './data_images/chinigura (351).xml',
#  './data_images/chinigura (352).xml',
#  './data_images/chinigura (353).xml',
#  './data_images/chinigura (354).xml',
#  './data_images/chinigura (355).xml',
#  './data_images/chinigura (356).xml',
#  './data_images/chinigura (357).xml',
#  './data_images/chinigura (358).xml',
#  './data_images/chinigura (359).xml',
#  './data_images/chinigura (36).xml',
#  './data_images/chinigura (360).xml',
#  './data_images/chinigura (361).xml',
#  './data_images/chinigura (362).xml',
#  './data_images/chinigura (363).xml',
#  './data_images/chinigura (364).xml',
#  './data_images/chinigura (365).xml',
#  './data_images/chinigura (366).xml',
#  './data_images/chinigura (367).xml',
#  './data_images/chinigura (368).xml',
#  './data_images/chinigura (369).xml',
#  './data_images/chinigura (37).xml',
#  './data_images/chinigura (370).xml',
#  './data_images/chinigura (371).xml',
#  './data_images/chinigura (372).xml',
#  './data_images/chinigura (373).xml',
#  './data_images/chinigura (374).xml',
#  './data_images/chinigura (375).xml',
#  './data_images/chinigura (376).xml',
#  './data_images/chinigura (377).xml',
#  './data_images/chinigura (378).xml',
#  './data_images/chinigura (379).xml',
#  './data_images/chinigura (38).xml',
#  './data_images/chinigura (380).xml',
#  './data_images/chinigura (381).xml',
#  './data_images/chinigura (382).xml',
#  './data_images/chinigura (383).xml',
#  './data_images/chinigura (384).xml',
#  './data_images/chinigura (385).xml',
#  './data_images/chinigura (386).xml',
#  './data_images/chinigura (387).xml',
#  './data_images/chinigura (388).xml',
#  './data_images/chinigura (389).xml',
#  './data_images/chinigura (39).xml',
#  './data_images/chinigura (390).xml',
#  './data_images/chinigura (391).xml',
#  './data_images/chinigura (392).xml',
#  './data_images/chinigura (393).xml',
#  './data_images/chinigura (394).xml',
#  './data_images/chinigura (395).xml',
#  './data_images/chinigura (396).xml',
#  './data_images/chinigura (397).xml',
#  './data_images/chinigura (398).xml',
#  './data_images/chinigura (399).xml',
#  './data_images/chinigura (4).xml',
#  './data_images/chinigura (40).xml',
#  './data_images/chinigura (400).xml',
#  './data_images/chinigura (401).xml',
#  './data_images/chinigura (402).xml',
#  './data_images/chinigura (403).xml',
#  './data_images/chinigura (404).xml',
#  './data_images/chinigura (405).xml',
#  './data_images/chinigura (406).xml',
#  './data_images/chinigura (407).xml',
#  './data_images/chinigura (408).xml',
#  './data_images/chinigura (409).xml',
#  './data_images/chinigura (41).xml',
#  './data_images/chinigura (410).xml',
#  './data_images/chinigura (411).xml',
#  './data_images/chinigura (412).xml',
#  './data_images/chinigura (413).xml',
#  './data_images/chinigura (414).xml',
#  './data_images/chinigura (415).xml',
#  './data_images/chinigura (416).xml',
#  './data_images/chinigura (417).xml',
#  './data_images/chinigura (418).xml',
#  './data_images/chinigura (419).xml',
#  './data_images/chinigura (42).xml',
#  './data_images/chinigura (420).xml',
#  './data_images/chinigura (421).xml',
#  './data_images/chinigura (422).xml',
#  './data_images/chinigura (423).xml',
#  './data_images/chinigura (424).xml',
#  './data_images/chinigura (425).xml',
#  './data_images/chinigura (426).xml',
#  './data_images/chinigura (427).xml',
#  './data_images/chinigura (428).xml',
#  './data_images/chinigura (429).xml',
#  './data_images/chinigura (43).xml',
#  './data_images/chinigura (430).xml',
#  './data_images/chinigura (431).xml',
#  './data_images/chinigura (432).xml',
#  './data_images/chinigura (433).xml',
#  './data_images/chinigura (434).xml',
#  './data_images/chinigura (435).xml',
#  './data_images/chinigura (436).xml',
#  './data_images/chinigura (437).xml',
#  './data_images/chinigura (438).xml',
#  './data_images/chinigura (439).xml',
#  './data_images/chinigura (44).xml',
#  './data_images/chinigura (440).xml',
#  './data_images/chinigura (441).xml',
#  './data_images/chinigura (442).xml',
#  './data_images/chinigura (443).xml',
#  './data_images/chinigura (444).xml',
#  './data_images/chinigura (445).xml',
#  './data_images/chinigura (446).xml',
#  './data_images/chinigura (447).xml',
#  './data_images/chinigura (448).xml',
#  './data_images/chinigura (449).xml',
#  './data_images/chinigura (45).xml',
#  './data_images/chinigura (450).xml',
#  './data_images/chinigura (451).xml',
#  './data_images/chinigura (452).xml',
#  './data_images/chinigura (453).xml',
#  './data_images/chinigura (454).xml',
#  './data_images/chinigura (455).xml',
#  './data_images/chinigura (456).xml',
#  ...]

# %%
# step-2: read xml files
# from each xml file we need to extract
# filename, size(width, height), object(name, xmin, xmax, ymin, ymax)
def extract_text(filename):
    tree = et.parse(filename)
    root = tree.getroot()

    # extract filename
    image_name = root.find('filename').text
    # width and height of the image
    width = root.find('size').find('width').text
    height = root.find('size').find('height').text
    objs = root.findall('object')
    parser = []
    for obj in objs:
        name = obj.find('name').text
        bndbox = obj.find('bndbox')
        xmin = bndbox.find('xmin').text
        xmax = bndbox.find('xmax').text
        ymin = bndbox.find('ymin').text
        ymax = bndbox.find('ymax').text
        parser.append([image_name, width, height, name,xmin,xmax,ymin,ymax])
        
    return parser

# %%
parser_all = list(map(extract_text,xmlfiles))

# %%
data = reduce(lambda x, y : x+y,parser_all)

# %%
df = pd.DataFrame(data,columns = ['filename','width','height','name','xmin','xmax','ymin','ymax'])

# %%
df.head()
# Out:
#             filename width height     name xmin xmax ymin ymax
# 0    basmati (1).png   300    300  Basmati  123  163  121  183
# 1   basmati (10).png   300    300  Basmati  135  177  113  171
# 2  basmati (100).png   300    300  Basmati  134  191  133  182
# 3  basmati (101).png   300    300  Basmati  116  164  142  204
# 4  basmati (102).png   300    300  Basmati  117  164  142  203

# %%
df.shape
# Out:
# (3116, 8)

# %%
df['name'].value_counts()
# Out:
# Nazirshail    634
# Paijam        630
# Jirashail     625
# Chinigura     624
# Basmati       603
# Name: name, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3116 entries, 0 to 3115
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  3116 non-null   object
#  1   width     3116 non-null   object
#  2   height    3116 non-null   object
#  3   name      3116 non-null   object
#  4   xmin      3116 non-null   object
#  5   xmax      3116 non-null   object
#  6   ymin      3116 non-null   object
#  7   ymax      3116 non-null   object
# dtypes: object(8)
# memory usage: 194.9+ KB

# %%
# type conversion
cols = ['width','height','xmin','xmax','ymin','ymax']
df[cols] = df[cols].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3116 entries, 0 to 3115
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  3116 non-null   object
#  1   width     3116 non-null   int32
#  2   height    3116 non-null   int32
#  3   name      3116 non-null   object
#  4   xmin      3116 non-null   int32
#  5   xmax      3116 non-null   int32
#  6   ymin      3116 non-null   int32
#  7   ymax      3116 non-null   int32
# dtypes: int32(6), object(2)
# memory usage: 121.8+ KB

# %%
# center x, center y
df['center_x'] = ((df['xmax']+df['xmin'])/2)/df['width']
df['center_y'] = ((df['ymax']+df['ymin'])/2)/df['height']
# w 
df['w'] = (df['xmax']-df['xmin'])/df['width']
# h 
df['h'] = (df['ymax']-df['ymin'])/df['height']

# %%
df.head()
# Out:
#             filename  width  height     name  xmin  xmax  ymin  ymax  \
# 0    basmati (1).png    300     300  Basmati   123   163   121   183
# 1   basmati (10).png    300     300  Basmati   135   177   113   171
# 2  basmati (100).png    300     300  Basmati   134   191   133   182
# 3  basmati (101).png    300     300  Basmati   116   164   142   204
# 4  basmati (102).png    300     300  Basmati   117   164   142   203
#
#    center_x  center_y         w         h
# 0  0.476667  0.506667  0.133333  0.206667
# 1  0.520000  0.473333  0.140000  0.193333
# 2  0.541667  0.525000  0.190000  0.163333
# 3  0.466667  0.576667  0.160000  0.206667
# 4  0.468333  0.575000  0.156667  0.203333

# %% [markdown]
# # split data into train and test

# %%
images = df['filename'].unique()

# %%
len(images)
# Out:
# 3116

# %%
# 80% train and 20% test
img_df = pd.DataFrame(images,columns=['filename'])
img_train = tuple(img_df.sample(frac=0.8)['filename']) # shuffle and pick 80% of images

# %%
img_test = tuple(img_df.query(f'filename not in {img_train}')['filename']) # take rest 20% images

# %%
len(img_train), len(img_test)
# Out:
# (2493, 623)

# %%
train_df = df.query(f'filename in {img_train}')
test_df = df.query(f'filename in {img_test}')

# %%
train_df.head()
# Out:
#             filename  width  height     name  xmin  xmax  ymin  ymax  \
# 1   basmati (10).png    300     300  Basmati   135   177   113   171
# 2  basmati (100).png    300     300  Basmati   134   191   133   182
# 3  basmati (101).png    300     300  Basmati   116   164   142   204
# 4  basmati (102).png    300     300  Basmati   117   164   142   203
# 5  basmati (103).png    300     300  Basmati   117   189   140   169
#
#    center_x  center_y         w         h
# 1  0.520000  0.473333  0.140000  0.193333
# 2  0.541667  0.525000  0.190000  0.163333
# 3  0.466667  0.576667  0.160000  0.206667
# 4  0.468333  0.575000  0.156667  0.203333
# 5  0.510000  0.515000  0.240000  0.096667

# %%
test_df.head()
# Out:
#              filename  width  height     name  xmin  xmax  ymin  ymax  \
# 0     basmati (1).png    300     300  Basmati   123   163   121   183
# 10  basmati (108).png    300     300  Basmati   146   175   117   191
# 30  basmati (126).png    300     300  Basmati   121   189   150   186
# 39  basmati (134).png    300     300  Basmati   126   196   154   180
# 41  basmati (136).png    300     300  Basmati   146   179   136   200
#
#     center_x  center_y         w         h
# 0   0.476667  0.506667  0.133333  0.206667
# 10  0.535000  0.513333  0.096667  0.246667
# 30  0.516667  0.560000  0.226667  0.120000
# 39  0.536667  0.556667  0.233333  0.086667
# 41  0.541667  0.560000  0.110000  0.213333

# %% [markdown]
# # Assign id number to object names

# %%
# label encoding
def label_encoding(x):
    labels = {'Nazirshail':0, 'Paijam':1, 'Jirashail':2, 'Chinigura':3, 'Basmati':4}
    return labels[x]

# %%
train_df['id'] = train_df['name'].apply(label_encoding)
test_df['id'] = test_df['name'].apply(label_encoding)

# %%
train_df.head(10)
# Out:
#              filename  width  height     name  xmin  xmax  ymin  ymax  \
# 1    basmati (10).png    300     300  Basmati   135   177   113   171
# 2   basmati (100).png    300     300  Basmati   134   191   133   182
# 3   basmati (101).png    300     300  Basmati   116   164   142   204
# 4   basmati (102).png    300     300  Basmati   117   164   142   203
# 5   basmati (103).png    300     300  Basmati   117   189   140   169
# 6   basmati (104).png    300     300  Basmati   120   188   140   173
# 7   basmati (105).png    300     300  Basmati   125   188   131   181
# 8   basmati (106).png    300     300  Basmati   130   184   130   182
# 9   basmati (107).png    300     300  Basmati   149   176   120   190
# 11  basmati (109).png    300     300  Basmati   138   213   146   171
#
#     center_x  center_y         w         h  id
# 1   0.520000  0.473333  0.140000  0.193333   4
# 2   0.541667  0.525000  0.190000  0.163333   4
# 3   0.466667  0.576667  0.160000  0.206667   4
# 4   0.468333  0.575000  0.156667  0.203333   4
# 5   0.510000  0.515000  0.240000  0.096667   4
# 6   0.513333  0.521667  0.226667  0.110000   4
# 7   0.521667  0.520000  0.210000  0.166667   4
# 8   0.523333  0.520000  0.180000  0.173333   4
# 9   0.541667  0.516667  0.090000  0.233333   4
# 11  0.585000  0.528333  0.250000  0.083333   4

# %% [markdown]
# # Save Image and Labels in text

# %%
import os
from shutil import move

# %%
train_folder = 'data_images/train'
test_folder = 'data_images/test'


os.mkdir(train_folder)
os.mkdir(test_folder)

# %%
cols = ['filename','id','center_x','center_y', 'w', 'h']
groupby_obj_train = train_df[cols].groupby('filename')
groupby_obj_test = test_df[cols].groupby('filename')

# %%
#groupby_obj_train.get_group('000009.jpg').set_index('filename').to_csv('sample.txt',index=False,header=False)
# save each image in train/test folder and repective labels in .txt
def save_data(filename, folder_path, group_obj):
    # move image
    src = os.path.join('data_images',filename)
    dst = os.path.join(folder_path,filename)
    move(src,dst) # move image to the destination folder
    
    # save the labels
    text_filename = os.path.join(folder_path,
                                 os.path.splitext(filename)[0]+'.txt')
    group_obj.get_group(filename).set_index('filename').to_csv(text_filename,sep=' ',index=False,header=False)

# %%
filename_series = pd.Series(groupby_obj_train.groups.keys())

# %%
filename_series.apply(save_data,args=(train_folder,groupby_obj_train))
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 2488    None
# 2489    None
# 2490    None
# 2491    None
# 2492    None
# Length: 2493, dtype: object

# %%
filename_series_test = pd.Series(groupby_obj_test.groups.keys())
filename_series_test.apply(save_data,args=(test_folder,groupby_obj_test))
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 618    None
# 619    None
# 620    None
# 621    None
# 622    None
# Length: 623, dtype: object
